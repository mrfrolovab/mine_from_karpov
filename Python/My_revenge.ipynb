# %%
import sys 

stdoutOrigin = sys.stdout 
sys.stdout = open("rev_result.txt", "w")

# %%
road_sign = 'а именно - парковка в зоне действия знака 3.27 "Остановка запрещена". Водитель пренебрегая дорожным знаком 3.27, создал помеху для движения транспортных средств. Описание транспортного средства нарушителя: Согласно КоАП РФ Статья 28.1 поводом для возбуждения административного дела может являться: сообщения и заявления от физических лиц; так же, поводом может стать фотосъемка или видеозапись. Статья 51 Конституции Российской Федерации, Статьи КоАП РФ: 25.6, 17.7, 17.9, 19.7, УК РФ Статья 306 — мне известны, ясны и понятны. Прошу: 1. Установить водителя управлявшего транспортным средством в указанное выше время, и возбудить в отношении него производство по делу об административном правонарушении по ч.1 ст. 12.19 КоАП РФ 2. По существу заявления и о принятых мерах направить мотивированный ответ в форме электронного документа на адрес up-and-coming@mail.ru. В ответе указать номер интернет-обращения для идентификации ответа.'
marking_line = 'а именно - припарковал свое транспортное средство в месте, где расстояние между сплошной линией разметки, разделительной полосой или противоположным краем проезжей части и остановившимся транспортным средством менее 3 м. Согласно статье 1 Федерального закона от 10.12.1995 г. № 196-ФЗ «О безопасности дорожного движения» в качестве задачи указанного Федерального закона определена охрана жизни, здоровья и имущества граждан, защита их прав и законных интересов, общества и государства путем предупреждения дорожно-транспортных происшествий, снижения тяжести их последствий. В пунктах 12.4, 12.5 Постановления Правительства РФ от 23.10.1993 г. № 1090 "О Правилах дорожного движения" прямо обозначены случаи запрета остановки и стоянки транспортных средств. В разделе 12 Постановления Правительства РФ от 23.10.1993 г. № 1090 и в в ред. Постановления Правительства РФ от 24.01.2001 № 67 "О Правилах дорожного движения" регламентирован порядок и правила остановки транспортных средств. В статье 12.19 Кодекса Российской Федерации об административных правонарушениях от 30.12.2001 г. № 195-ФЗ установлена ответственность за нарушение правил остановки или стоянки транспортных средств. Согласно пункту второму Положения «О государственной инспекции безопасности дорожного движения Министерства внутренних дел Российской Федерации» от 15 июня 1998 года № 711 ГИБДД занимается вопросами обеспечения безопасности дорожного движения, проведением мероприятий по предупреждению дорожно-транспортных происшествий и снижению тяжести их последствий в целях охраны жизни, здоровья и имущества граждан, защиты их прав и законных интересов, а также интересов общества и государства, а согласно подпункту «З» пункта 11 того же положения в обязанности ГИБДД входит осуществление в соответствии с законодательством Российской Федерации производства по делам об административных правонарушениях. Согласно КоАП РФ Статья 28.1 поводом для возбуждения административного дела может являться: сообщения и заявления от физических лиц; так же, поводом может стать фотосъемка или видеозапись. Статья 51 Конституции Российской Федерации, Статьи КоАП РФ: 25.6, 17.7, 17.9, 19.7, УК РФ Статья 306 — мне известны, ясны и понятны. На основании изложенного и руководствуясь ФЗ «О порядке рассмотрения обращений граждан Российской Федерации», Положением «О государственной инспекции безопасности дорожного движения Министерства внутренних дел Российской Федерации» от 15 июня 1998 года № 711, прошу: -проверить действия лиц на наличие состава административного правонарушения, предусмотренного статьей 12.19 КоАП РФ, привлечь виновных к предусмотренной законом ответственности; -ограничить несанкционированную остановку и (или) стоянку транспортных средств в указанном месте. -по существу заявления и о принятых мерах направить мотивированный ответ в форме электронного документа на адрес up-and-coming@mail.ru. В ответе указать номер интернет-обращения для идентификации ответа.'
и запрета остановки и стоянки транспортных средств. В разделе 12 Постановления Правительства РФ от 23.10.1993 г. N 1090 "О Правилах дорожного движения" регламентирован порядок и правила остановки транспортных средств. В статье 12.19 Кодекса Российской Федерации об административных правонарушениях от 30.12.2001 г. N 195-ФЗ установлена ответственность за нарушение правил остановки или стоянки транспортных средств. Согласно пункту второму Положения «О государственной инспекции безопасности дорожного движения Министерства внутренних дел Российской Федерации» от 15 июня 1998 года N 711 ГИБДД занимается вопросами обеспечения безопасности дорожного движения, проведением мероприятий по предупреждению дорожно-транспортных происшествий и снижению тяжести их последствий в целях охраны жизни, здоровья и имущества граждан, защиты их прав и законных интересов, а также интересов общества и государства, а согласно подпункту «З» пункта 11 того же положения в обязанности ГИБДД входит осуществление в соответствии с законодательством Российской Федерации производства по делам об административных правонарушениях. Согласно КоАП РФ Статья 28.1 поводом для возбуждения административного дела может являться: сообщения и заявления от физических лиц; так же, поводом может стать фотосъемка или видеозапись. Статья 51 Конституции Российской Федерации, Статьи КоАП РФ: 25.6, 17.7, 17.9, 19.7, УК РФ Статья 306 — мне известны, ясны и понятны. На основании изложенного и руководствуясь ФЗ «О порядке рассмотрения обращений граждан Российской Федерации», Положением «О государственной инспекции безопасности дорожного движения Министерства внутренних дел Российской Федерации» от 15 июня 1998 года N 711, прошу: -проверить действия лиц на наличие состава административного правонарушения, предусмотренного статьей 12.19 КоАП РФ, привлечь виновных к предусмотренной законом ответственности; -ограничить несанкционированную остановку и (или) стоянку транспортных средств в указанном месте. -по существу заявления и о принятых мерах направить мотивированный ответ в форме электронного документа на адрес up-and-coming@mail.ru. В ответе указать номер интернет-обращения для идентификации ответа.'

date_and_time = '30.12.2022 в 20:31'
adress_14, adress_16 = 'ул. Майора Филипова, 14', 'ул. Майора Филипова, 16'
region, region_14, region_25, region_27, region_28, region_41, region_138, region_774  = '125', '14', '25', '27', '28', '41', '138', '774'
car_number = ''
text = '{date_and_time}, {adress}, мной было обнаружено нарушение ПДД РФ водителем ТС гос. номер авто {car_number} {region},'

while car_number != 'стоп':
    car_number = input()
    if car_number == 'стоп':
        break
    elif car_number == 'к402кс': 
        print(text.format(date_and_time = date_and_time, adress = adress_14, car_number = car_number, region = region_14))
    elif car_number in 'о555хтм783авн555тк': 
        print(marking_line, text.format(date_and_time = date_and_time, adress = adress_14, car_number = car_number, region = region_25), sep = '\n')
    elif car_number in 'в536тоа770мр': 
        print(text.format(date_and_time = date_and_time, adress = adress_14, car_number = car_number, region = region_27))
    elif car_number == 'к166рр': 
        print(text.format(date_and_time = date_and_time, adress = adress_14, car_number = car_number, region = region_28))
    elif car_number == 'е281ав': 
        print(text.format(date_and_time = date_and_time, adress = adress_14, car_number = car_number, region = region_41))
    elif car_number == 'о221нх': 
        print(text.format(date_and_time = date_and_time, adress = adress_14, car_number = car_number, region = region_138))
    elif car_number == 'в248ех': 
        print(text.format(date_and_time = date_and_time, adress = adress_14, car_number = car_number, region = region_774))
    elif car_number == 'м783ав':
        print(text.format(date_and_time = date_and_time, adress = adress_14, car_number = car_number, region = region))
    else: print(text.format(date_and_time = date_and_time, adress = adress_16, car_number = car_number, region = region))
print(grass)
# Out:
# т416ор
# стоп

# %%
sys.stdout.close()
sys.stdout=stdoutOrigin
