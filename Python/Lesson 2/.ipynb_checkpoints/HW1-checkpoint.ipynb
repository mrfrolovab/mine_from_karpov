# %%
import pandas as pd
taxi = pd.read_csv(r'/mnt/HC_Volume_18315164/home-jupyter/jupyter-ale-frolov/Lesson 2/2_taxi_nyc.csv')
taxi
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp 01  pcp 06  pcp 24   sd
# ...

# %%
taxi.shape
# Out:
# (29101, 14)

# %%
taxi.dtypes
# Out:
# pickup_dt        object
# pickup_month     object
# borough          object
# pickups           int64
# hday             object
# spd             float64
# vsb             float64
# temp            float64
# dewp            float64
# slp             float64
# pcp 01          float64
# pcp 06          float64
# pcp 24          float64
# sd              float64
# dtype: object

# %%
taxi.columns
# Out:
# Index(['pickup_dt', 'pickup_month', 'borough', 'pickups', 'hday', 'spd', 'vsb',
#        'temp', 'dewp', 'slp', 'pcp 01', 'pcp 06', 'pcp 24', 'sd'],
#       dtype='object')

# %%
taxi = taxi.rename(columns = {'pcp 01': 'pcp_01',
                              'pcp 06': 'pcp_06',
                              'pcp 24': 'pcp_24'})
taxi
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd
# ...

# %%
# Переименовал колонки
taxi = taxi.rename(columns = {'pcp 01': 'pcp_01',
                              'pcp 06': 'pcp_06',
                              'pcp 24': 'pcp_24'})
taxi
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd
# ...

# %%
taxi.borough.value_counts()
# Out:
# Staten Island    4343
# Brooklyn         4343
# EWR              4343
# Queens           4343
# Bronx            4343
# Manhattan        4343
# Name: borough, dtype: int64

# %%
# Всего заказов (для проверки)
total_pickups = taxi.pickups.sum()
total_pickups
# Out:
# 14265773

# %%
# Наименьшее количество заказов
min_pickups = taxi.groupby('borough') \
                    .agg({'pickups': 'sum'}) \
                    .idxmin()
min_pickups
# Out:
# pickups    EWR
# dtype: object

# %%
# Районы, из которых по праздникам в среднем поступает больше заказов
weekends = taxi \
    .groupby(['borough', 'hday'], as_index = False) \
    .agg({'pickups': 'mean'})
weekends
# Out:
#           borough hday      pickups
# 0           Bronx    N    50.771073
# 1           Bronx    Y    48.065868
# 2        Brooklyn    N   534.727969
# 3        Brooklyn    Y   527.011976
# 4             EWR    N     0.023467
# 5             EWR    Y     0.041916
# 6       Manhattan    N  2401.302921
# 7       Manhattan    Y  2035.928144
# 8          Queens    N   308.899904
# 9          Queens    Y   320.730539
# 10  Staten Island    N     1.606082
# 11  Staten Island    Y     1.497006

# %%
# Для каждого района посчитайте число поездок по месяцам.
# Отсортируйте полученные значения по убыванию и сохраните результирующий датафрейм в pickups_by_mon_bor.
# Обратите внимание, что итоговый датасет должен состоять из 3-х колонок - pickup_month, borough, pickups.

pickups_by_mon_bor =
