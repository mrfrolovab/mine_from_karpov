# %% [markdown]
# # 5 УРОК СРАВНЕНИЕ СРЕДНИХ ЗНАЧЕНИЙ (ДИСПЕРСИОННЫЙ АНАЛИЗ) ЗАДАНИЯ

# %% [markdown]
# ## ШАГ 1
#
# Теоретическое распределение F-значения в дисперсионном анализе не является нормальным, а подчиняется распределению Фишера (F distribution). Вы можете посмотреть, как изменяется форма этого распределения в зависимости от числа степеней свободы (от количества групп и общего числа наблюдений). Обратите внимание, что F-значение всегда является положительным, поэтому, в отличие от T-критерия, мы рассчитываем вероятность отклонения только в правую сторону.
# https://gallery.shinyapps.io/dist_calc/﻿
#
# Задача
#
# Перейдем к задаче. Допустим, что при сравнении четырех групп между собой (по 5 наблюдений в каждой группе) вы получили F = 3.5, тогда:
#
# Подсказки

# %% [markdown]
# - **Как пользоваться сайтом?**
#     - в **Distribution** выберите вариант **F**
#     - в качестве **df1** указываете степени свободы **SSB** (количество групп минус 1)
#     - в качестве **df2** указываете степени свободы **SSW** (общее количество наблюдений минус количество групп)
#     - в **a** указываете нужное F-значение

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
P(X > 3.49) = 0.0404

# %% [markdown]
# ##### ОТВЕТ:
#
# Принимаем нулевую гипотезу о равенстве средних, т.к. p > 0.05
#
# #### Отклоняем нулевую гипотезу о равенстве средних, т.к. p < 0.05
#
# Отклоняем нулевую гипотезу о равенстве средних, т.к. p > 0.05
#
# Принимаем нулевую гипотезу о равенстве средних, т.к. p < 0.05

# %% [markdown]
# ## ШАГ 2
# Немного об обозначениях в дисперсионном анализе
# Когда мы делим значение межгрупповой суммы квадратов на соответствующее число степеней свободы (число групп минус один), мы тем самым усредняем полученный показатель. Усредненное значение межгрупповой суммы квадратов называется межгрупповым средним квадратом:
#
# MS
# bg
# ​
#  =
# df
# bg
# ​
#
# SSB
# ​
#  df
# bg
# ​
#  =m−1
#
# Отношение внутригрупповой суммы квадратов к соответствующему числу степеней свободы (число всех наблюдений минус число групп) — это внутригрупповой средний квадрат:
#
# MS
# wg
# ​
#  =
# df
# wg
# ​
#
# SSW
# ​
#  df
# wg
# ​
#  =N−m
#
# Поэтому формула F-значения (F-отношение) часто записывается как:
#
# F=
# MS
# wg
# ​
#
# MS
# bg
# ​
#
# ​
#
#
# Задание:
# Отметьте верное утверждение (утверждения)
#
# Подсказки

# %% [markdown]
# - **Что нужно знать для правильного ответа?**
#     - **SSB** и **SSW** независимы
#     - чем больше F, тем лучше
#     - дисперсионный анализ подходит для любого количества групп
#     - общая сумма квадратов отражает общую вариабельность, не скорректированную на размер выборки

# %% [markdown]
# ##### ОТВЕТ:
#
# #### Чем больше дисперсия внутри групп, тем больше значение внутригруппового квадрата (при неизменном количестве наблюдений)
#
# #### Общая сумма квадратов, деленная на число всех наблюдений минус один — это и есть дисперсия, рассчитанная для всех наших наблюдений без учета деления на группы
#
# Чем меньше значение F-отношения, тем больше шансов отклонить нулевую гипотезу (при сравнении трех групп по 10 наблюдений в каждой)
#
# При помощи дисперсионного анализа можно сравнить между собой только 2 группы
#
# Чем больше значение внутригруппового квадрата, тем обязательно больше значение межгруппового квадрата

# %% [markdown]
# ## ШАГ 3
# Отклонение нулевой гипотезы позволяет нам сделать следующий вывод:
#
# Подсказки

# %% [markdown]
# - **Какова нулевая гипотеза дисперсионного анализа?**
#
#     Что средние всех групп значимо не различаются. Любое отклонение от этого считается альтернативной гипотезой.

# %% [markdown]
# ##### ОТВЕТ:
#
# Все группы значимо различаются между собой
#
# #### Как минимум две группы значимо различаются
#
# Только две группы значимо различаются
#
# Значимых различий обнаружить не удалось

# %% [markdown]
# ## ШАГ 4
# Чтобы выяснить, как лучше преподавать статистику, преподаватели разбили студентов на пять групп. В каждой группе использовалась различная методика преподавания. В конце года каждая группа написала итоговую работу. Таким образом, сравнивалось пять групп по среднему баллу контрольной работы. Был применен однофакторный дисперсионный анализ, по результатам которого удалось отклонить нулевую гипотезу о равенстве средних.
#
# Сколько сравнений необходимо произвести, чтобы попарно сравнить все группы между собой?
#
# Подсказки

# %% [markdown]
# - **По какой формуле это можно сделать?**
#
#     Общую формулу можно посмотреть [тут](https://www.matburo.ru/tvart_sub.php?p=calc_C#:~:text=%D0%9D%D0%B0%20%D0%BA%D0%B0%D1%80%D1%82%D0%B8%D0%BD%D0%BA%D0%B5%20%D0%BD%D0%B0%D0%B3%D0%BB%D1%8F%D0%B4%D0%BD%D0%BE%20%D0%BF%D1%80%D0%BE%D0%B8%D0%BB%D0%BB%D1%8E%D1%81%D1%82%D1%80%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%BE%20%D0%BF%D0%BE%D0%BB%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D0%B5,Ckn%3Dn!), но для этого случая достаточно формулы $\frac{n(n-1)}{2}$, где $n$ - количество групп.
#
#   ![image.png](attachment:image.png)

# %%
(1*2*3*4*5)/(1*2 * 1*2*3)
# Out:
# 10.0

# %%
(5*(5-1))/2
# Out:
# 10.0

# %% [markdown]
# ##### OTBET:
# #### 10
#
# 15
#
# 6
#
# 5

# %% [markdown]
# ## ШАГ 5
# Необходимо ли применять поправку на множественное сравнение при сравнении групп из предыдущего вопроса между собой?
#
# Подсказки

# %% [markdown]
# - **Что такое проблема множественных сравнений?**
#
#     Это искусственное завышение вероятности ошибки I рода при сравнении групп больше 2.

# %% [markdown]
# ##### ОТВЕТ
# Да, т.к. возрастает вероятность совершить ошибку второго рода.
#
# Нет, т.к. снижается вероятность совершить ошибку второго рода.
#
# #### Да, т.к. возрастает вероятность совершить ошибку первого рода.
#
# Нет, т.к. снижается вероятность совершить ошибку первого рода.

# %% [markdown]
# ## ШАГ 6
# Курение считают основным фактором, предрасполагающим к хроническим заболеваниям легких. Однако пассивное курение таким фактором обычно не считается. Группа исследователей усомнилась в безвредности пассивного курения и исследовали проходимость дыхательных путей у некурящих, пассивных и активных курильщиков. В качестве зависимой переменной выступал один из показателей функции внешнего дыхания — максимальная объемная скорость середины выдоха. Исследователям удалось отклонить основную нулевую гипотезу о равенстве средних при p<0.05.
#
# Для попарного сравнения всех групп между собой использовалась поправка Бонферрони. Различия между группами признавались статистически достоверными, если p-уровень значимости:
#
# Подсказки

# %% [markdown]
# - **Как делается поправка Бонферрони?**
#
#     Мы берём наш исходный уровень значимости, делим его на количество попарных сравнений и получившееся число берём как новый уровень значимости.

# %%
0.05/3
# Out:
# 0.016666666666666666

# %% [markdown]
# ##### ОТВЕТ:
# меньше 0.05
#
# меньше 0.0001
#
# #### меньше 0.017
#
# меньше 0.02

# %% [markdown]
# ## ШАГ 7
# Предположим, мы хотим выяснить, есть ли значимые различия в успешности прохождения онлайн-курса по введению в статистику (итоговый балл) у представителей разных факультетов (биологи, математики, психологи) с учетом курса обучения (1, 3, 5 курсы).
#
# В таком случае:
#
# Подсказки

# %% [markdown]
# - **Что должно быть НП, а что ЗП?**
#     - НП - все номинативные переменные
#     - ЗП - непрерывная переменная

# %% [markdown]
# ##### ОТВЕТ:
# #### Итоговый балл — зависимая переменная, факультет и курс — независимые переменные
#
# Курс — зависимая переменная, факультет и итоговый балл — независимые переменные
#
# Факультет — зависимая переменная, курс и итоговый балл — независимые переменные

# %% [markdown]
# ## ШАГ 8
# Предположим, мы хотим выяснить, есть ли значимые различия в успешности прохождения онлайн-курса по введению в статистику (итоговый балл) у представителей разных факультетов (биологи, математики, психологи) с учетом курса обучения (1, 3, 5 курсы).
#
# Для проверки нулевой гипотезы о равенстве среднего итогового балла во всех группах осмысленнее всего применять:
#
# Подсказки

# %% [markdown]
# - **Что нужно учитывать для правильного ответа?**
#     - сколько групп мы сравниваем
#     - сколько у нас есть разбивок по группам

# %% [markdown]
# ##### ОТВЕТ:
# Критерий t-Стьюдента (сравнить все пары между собой, т.к. поправка на множественные сравнения не нужна в данном случае)
#
# #### Двухфакторный дисперсионный анализ
#
# Однофакторный дисперсионный анализ

# %% [markdown]
# ## ШАГ 9
# Компания, разрабатывающая мобильные телефоны, перед выпуском двух новых моделей (№1 и №2), решила выяснить, как потенциальные пользователи воспринимают эти новинки. Для этого компания набрала фокус-группу (100 мужчин, 100 женщин) и попросила участников оценить дизайн новых моделей телефонов от 1 до 100. Чтобы проанализировать полученные результаты, был применен двухфакторный дисперсионный анализ (зависимая переменная – оценка испытуемых по 100-балльной шкале, независимые переменные (факторы) – номер модели и пол испытуемых).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Соотнесите графики результатов (A, B, C, D) и различные результаты исследования:
#
# Подсказки

# %% [markdown]
# - **Как интерпретировать графики?**
#
#     На оси **y** отображается стоимость, на оси **x** отображается эффект модели телефона, **цветом** помечен пол. Соответственно:
#
#     - эффект модели отображается в области именно осей **x** и **y**
#     - эффект пола связан с тем, перекрываются ли цветные линии
#     - взаимодействие проявляется в противоположных эффектах

# %% [markdown]
# ##### ОТВЕТ:
#
# C значимый эффект для обоих факторов
#
# B значимый эффект только для фактора пола участников исследования
#
# A значимый эффект только для фактора модели телефона
#
# D значимое взаимодействие факторов

# %% [markdown]
# ## ШАГ 10
# Взаимодействие факторов в дисперсионном анализе означает, что:
#
# Подсказки

# %% [markdown]
# - **В чём суть взаимодействия факторов?**
#     - у нас есть несколько факторов
#     - одни факторы зависимы от значений других

# %% [markdown]
# ##### ОТВЕТ:
#
# Только один фактор оказывает значимое влияние на зависимую переменную
#
# Нет возможности отклонить нулевую гипотезу о равенстве средних значений
#
# #### Влияние одного фактора по-разному проявляется на зависимую переменную в зависимости от градаций другого фактора

# %% [markdown]
# ## ШАГ 11
# Причиной отклонения нулевой гипотезы в многофакторном дисперсионном анализе (о равенстве средних во всех группах) может стать:
#
# Подсказки

# %% [markdown]
# - **Какова нулевая гипотеза многофакторного дисперсионного анализа?**
#
#     Средние значимо не различаются по градациям всех факторов. Если есть какое-то отклонение от этого - отвергаем нулевую гипотезу в пользу альтернативной.

# %% [markdown]
# ##### ОТВЕТ:
#
# Значимый эффект одного из факторов
#
# Значимый эффект для всех факторов
#
# #### Каждый из предложенных вариантов
#
# Значимое взаимодействие факторов

# %% [markdown]
# ## ШАГ 12
#
# Могут ли очень заметные выбросы негативно повлиять на результаты дисперсионного анализа?
#
# Подсказки

# %% [markdown]
# - **Могут ли выбросы повлиять на дисперсионный анализ?**
#
#     В дисперсионный анализ включены как средние, так и дисперсия данных. Оба параметра чувствительны к выбросам.

# %% [markdown]
# ##### ОТВЕТ:
#
# #### Да, так как могут нежелательно повлиять на значения средних межгрупповых и внутригрупповых квадратов (особенно в случае небольшого количества наблюдений)
#
# Да, но только в случае многофакторного анализа
#
# Нет, т.к. дисперсионный анализ сравнивает дисперсии групп, а не средние значения

# %% [markdown]
# ## ШАГ 13
#
# Укажите верные высказывания относительно дисперсионного анализа:
#
# Подсказки

# %% [markdown]
# - **Как считаются степени свободы для межгруппового квадрата?**
#
#     Это количество групп минус один.
#
# - **Что такое поправка Бонферрони?**
#
#     Это один из методов коррекции на множественные сравнения.

# %% [markdown]
# ##### ОТВЕТ:
#
# #### Поправка Бонферрони применяется для коррекции p-уровня значимости при множественных сравнениях
#
# Дисперсионный анализ не может проверять гипотезы о влиянии сразу 5 факторов на зависимую переменную (максимум два фактора могут быть включены в модель)
#
# #### При увеличении числа групп число степеней свободы для межгруппового среднего квадрата также увеличивается

# %% [markdown]
# ## ШАГ 14
# Укажите, какие ограничения желательно проверять при использовании дисперсионного анализа:
#
# Подсказки

# %% [markdown]
# - **Какие допущения у дисперсионного анализа?**
#
#     Нормальность распределений и однородность их дисперсий.

# %% [markdown]
# ##### ОТВЕТ:
#
# F-значение не должно превышать 30
#
# Количество групп (не больше трех), и гомогенность дисперсий (однородность)
#
# #### Нормальное распределение зависимой переменной в группах, гомогенность (однородность) дисперсий
#
# Приблизительное равенство межгруппового и внутригруппового среднего квадрата
